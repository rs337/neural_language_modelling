# %%
import torch

# %%
torch.mps.is_available()
# Out:
# True

# %%
torch.mps.device_count()
# Out:
# 1

# %% [markdown]
# ### Tesnors
# - a high dimensional array, to be used on CPU or macbook silicon

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
tensor = torch.Tensor([[1,2,3],[4,5,6]])
tensor
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])

# %%
arr * 5
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30]])

# %%
tensor * 5
# Out:
# tensor([[ 5., 10., 15.],
#         [20., 25., 30.]])

# %%
arr.sum()
# Out:
# np.int64(21)

# %%
tensor.sum()
# Out:
# tensor(21.)

# %%
tensor = torch.from_numpy(arr)
tensor
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
np.ones((2,4))
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
torch.ones((2,4))
# Out:
# tensor([[1., 1., 1., 1.],
#         [1., 1., 1., 1.]])

# %%
np.random.random((2,4))
# Out:
# array([[0.12107185, 0.9414178 , 0.18678241, 0.96748378],
#        [0.72212599, 0.89915494, 0.81873348, 0.50606407]])

# %%
torch.rand(2,4)
# Out:
# tensor([[0.4417, 0.9756, 0.5490, 0.3977],
#         [0.3749, 0.4921, 0.9190, 0.4052]])

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.device
# Out:
# 'cpu'

# %%
tensor.shape
# Out:
# torch.Size([2, 3])

# %%
tensor.device
# Out:
# device(type='cpu')

# %%
arr.to_device('mps')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 arr.to_device('mps')
#
# ValueError: Unsupported device: mps. Only 'cpu' is accepted.

# %%
tensor = tensor.to('mps')

# %%
tensor.sum()
# Out:
# tensor(21, device='mps:0')

# %%
tensor.cpu().numpy()
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
