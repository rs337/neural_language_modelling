# %%
import numpy as np

def matrix_mul(matrix1, matrix2):
    return matrix1 * matrix2

matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[4, 3], [2, 1]])
print(matri)

matrix_mul(matrix1, matrix2)
# Out:
# array([[4, 6],
#        [6, 4]])

# %%
matrix1 = [[1,2], [3,4]]
matrix2 = [[4,3], [2,1]]

print(matrix1[0][1], matrix2[1][0])

def matrix_mul(m1, m2):
    entry1 = (matrix1[0][0] * matrix2[0][0]) + (matrix1[0][1] * matrix2[1][0])
    entry2 = (matrix1[0][0] * matrix2[0][1]) + (matrix1[0][1] * matrix2[1][1])
    entry3 = (matrix1[1][0] * matrix2[0][0]) + (matrix1[1][1] * matrix2[1][0])
    entry4 = (matrix1[1][0] * matrix2[0][1]) + (matrix1[1][1] * matrix2[1][1])
    return [[entry1, entry2], [entry3, entry4]]

matrix_mul(matrix1,matrix2)
# Out:
# 2 2
# [[8, 5], [20, 13]]
