# %%
import optuna
import torch
import pandas as pd
from torch import nn
from torch.utils.data import Dataset, DataLoader
from sklearn.feature_extraction.text import TfidfVectorizer


def preprocess_agnews(csv_file):
    '''Load and preprocess AG News data'''
    df = pd.read_csv(csv_file, header = None)
    df = df[df[0] !=1]
    df['label'] = df[0] - 2
    df['text'] = [" ".join((title, body)) for title, body in zip(df[1], df[2])]
    return df[['text', 'label']]

class TextDataset(Dataset):
    '''Class for creating the vectoriser and features'''
    def __init__(self, dataframe, max_features=1500, vectoriser=None):
        self.texts = dataframe['text'].tolist()
        self.labels = dataframe['label'].tolist()
        
        # TF-IDF: fit on training, reuse for testing
        if vectoriser is None:
            # Training: create and fit
            self.vectoriser = TfidfVectorizer(max_features=max_features, stop_words='english')
            self.features = self.vectoriser.fit_transform(self.texts)
        else:
            # Testing: use provided vectoriser
            self.vectoriser = vectoriser
            self.features = self.vectoriser.transform(self.texts)
        
        # Convert sparse matrix to dense tensor (TF-IDF returns sparse)
        self.features = torch.tensor(self.features.toarray(), dtype=torch.float32)
        self.labels = torch.tensor(self.labels, dtype=torch.long)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        # Just return pre-computed vectors
        return self.features[idx], self.labels[idx]

def create_model(trial):
    """Let Optuna choose the architecture."""
    n_layers = trial.suggest_int("n_layers", 1, 3)
    layers = []
    
    in_features = 1500  # Your TF-IDF features
    for i in range(n_layers):
        out_features = trial.suggest_int(f"n_units_l{i}", 64, 512)
        layers.append(nn.Linear(in_features, out_features))
        layers.append(nn.ReLU())
        in_features = out_features
    
    layers.append(nn.Linear(in_features, 3))  # Output layer
    return nn.Sequential(*layers)


def objective(trial):
    """Optuna calls this to evaluate each configuration."""
    
    # Hyperparameters to search
    lr = trial.suggest_float("lr", 1e-4, 1e-1, log=True)
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 128])
    optimizer_name = trial.suggest_categorical("optimizer", ["SGD", "Adam", "RMSprop"])
    
    # Create model with suggested architecture
    model = create_model(trial)
    
    # Create dataloaders with suggested batch size
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    # Select optimizer
    if optimizer_name == "SGD":
        optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    elif optimizer_name == "Adam":
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    else:
        optimizer = torch.optim.RMSprop(model.parameters(), lr=lr)
    
    loss_fn = nn.CrossEntropyLoss()
    
    # Train for a few epochs
    for epoch in range(5):
        model.train()
        for X, y in train_loader:
            optimizer.zero_grad()
            loss = loss_fn(model(X), y)
            loss.backward()
            optimizer.step()
    
    # Evaluate and return accuracy (Optuna maximizes this)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X, y in test_loader:
            pred = model(X).argmax(1)
            correct += (pred == y).sum().item()
            total += len(y)
    
    return correct / total  # Return accuracy

# Dataset
train_df = preprocess_agnews('../W2_feedfoward_neural_networks/agnews_train.csv')
test_df = preprocess_agnews('../W2_feedfoward_neural_networks/agnews_test.csv')

train_dataset = TextDataset(train_df, max_features=1500)
test_dataset = TextDataset(test_df, vectoriser=train_dataset.vectoriser)  # Passing the fitted vectoriser

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Run the search
study = optuna.create_study(direction="maximize")  # Maximize accuracy
study.optimize(objective, n_trials=50)  # Try 50 configurations

# Best results
print(f"Best accuracy: {study.best_value}")
print(f"Best hyperparameters: {study.best_params}")
# Out:
# [I 2026-01-30 10:48:37,173] A new study created in memory with name: no-name-f4e988a7-05b1-4e87-8003-9fe3525af864
# [I 2026-01-30 10:48:42,285] Trial 0 finished with value: 0.905438596491228 and parameters: {'lr': 0.03537734821644287, 'batch_size': 128, 'optimizer': 'Adam', 'n_layers': 2, 'n_units_l0': 70, 'n_units_l1': 365}. Best is trial 0 with value: 0.905438596491228.
# [I 2026-01-30 10:48:52,260] Trial 1 finished with value: 0.9007017543859649 and parameters: {'lr': 0.04249611927659274, 'batch_size': 32, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 223}. Best is trial 0 with value: 0.905438596491228.
# [I 2026-01-30 10:48:57,635] Trial 2 finished with value: 0.3385964912280702 and parameters: {'lr': 0.0012419208707766783, 'batch_size': 128, 'optimizer': 'SGD', 'n_layers': 2, 'n_units_l0': 277, 'n_units_l1': 339}. Best is trial 0 with value: 0.905438596491228.
# [I 2026-01-30 10:49:02,901] Trial 3 finished with value: 0.9091228070175439 and parameters: {'lr': 0.008316282955915036, 'batch_size': 128, 'optimizer': 'Adam', 'n_layers': 3, 'n_units_l0': 111, 'n_units_l1': 182, 'n_units_l2': 231}. Best is trial 3 with value: 0.9091228070175439.
# [I 2026-01-30 10:49:09,621] Trial 4 finished with value: 0.8982456140350877 and parameters: {'lr': 0.03842378762703265, 'batch_size': 64, 'optimizer': 'SGD', 'n_layers': 2, 'n_units_l0': 400, 'n_units_l1': 158}. Best is trial 3 with value: 0.9091228070175439.
# [I 2026-01-30 10:49:16,716] Trial 5 finished with value: 0.913859649122807 and parameters: {'lr': 0.0003830860769367642, 'batch_size': 128, 'optimizer': 'Adam', 'n_layers': 3, 'n_units_l0': 183, 'n_units_l1': 199, 'n_units_l2': 499}. Best is trial 5 with value: 0.913859649122807.
# [I 2026-01-30 10:49:21,714] Trial 6 finished with value: 0.5798245614035088 and parameters: {'lr': 0.04244290806880899, 'batch_size': 128, 'optimizer': 'SGD', 'n_layers': 3, 'n_units_l0': 162, 'n_units_l1': 273, 'n_units_l2': 258}. Best is trial 5 with value: 0.913859649122807.
# [I 2026-01-30 10:49:33,858] Trial 7 finished with value: 0.9080701754385965 and parameters: {'lr': 0.024973038471850468, 'batch_size': 64, 'optimizer': 'Adam', 'n_layers': 2, 'n_units_l0': 370, 'n_units_l1': 281}. Best is trial 5 with value: 0.913859649122807.
# [I 2026-01-30 10:49:40,574] Trial 8 finished with value: 0.35228070175438597 and parameters: {'lr': 0.0003203638766660291, 'batch_size': 32, 'optimizer': 'SGD', 'n_layers': 1, 'n_units_l0': 203}. Best is trial 5 with value: 0.913859649122807.
# [I 2026-01-30 10:49:46,025] Trial 9 finished with value: 0.9166666666666666 and parameters: {'lr': 0.0007752021326943325, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 320}. Best is trial 9 with value: 0.9166666666666666.
# [I 2026-01-30 10:49:55,324] Trial 10 finished with value: 0.9133333333333333 and parameters: {'lr': 0.00012192195502127041, 'batch_size': 64, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 495}. Best is trial 9 with value: 0.9166666666666666.
# [I 2026-01-30 10:50:04,807] Trial 11 finished with value: 0.9159649122807018 and parameters: {'lr': 0.0008379481254485856, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 3, 'n_units_l0': 312, 'n_units_l1': 494, 'n_units_l2': 502}. Best is trial 9 with value: 0.9166666666666666.
# [I 2026-01-30 10:50:10,587] Trial 12 finished with value: 0.9194736842105263 and parameters: {'lr': 0.001766513722360865, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 343}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:50:16,823] Trial 13 finished with value: 0.9156140350877193 and parameters: {'lr': 0.003826184481022285, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 412}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:50:22,424] Trial 14 finished with value: 0.9187719298245614 and parameters: {'lr': 0.0019916312524003873, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 319}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:50:39,100] Trial 15 finished with value: 0.9136842105263158 and parameters: {'lr': 0.0036823661267764802, 'batch_size': 32, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 473}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:50:44,377] Trial 16 finished with value: 0.9157894736842105 and parameters: {'lr': 0.009824551821653017, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 264}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:50:50,609] Trial 17 finished with value: 0.9187719298245614 and parameters: {'lr': 0.0019097994220263126, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 2, 'n_units_l0': 360, 'n_units_l1': 75}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:00,813] Trial 18 finished with value: 0.9150877192982456 and parameters: {'lr': 0.007579160722569009, 'batch_size': 32, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 253}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:09,209] Trial 19 finished with value: 0.9163157894736842 and parameters: {'lr': 0.002157994953633372, 'batch_size': 64, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 417}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:16,758] Trial 20 finished with value: 0.9145614035087719 and parameters: {'lr': 0.0002960334787538196, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 2, 'n_units_l0': 332, 'n_units_l1': 480}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:23,057] Trial 21 finished with value: 0.9131578947368421 and parameters: {'lr': 0.0017505941893347441, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 2, 'n_units_l0': 361, 'n_units_l1': 74}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:29,883] Trial 22 finished with value: 0.91 and parameters: {'lr': 0.0046787054353659395, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 2, 'n_units_l0': 450, 'n_units_l1': 66}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:35,566] Trial 23 finished with value: 0.9145614035087719 and parameters: {'lr': 0.0007408470289249535, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 334}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:41,483] Trial 24 finished with value: 0.9124561403508772 and parameters: {'lr': 0.0022064925590907195, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 383}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:48,130] Trial 25 finished with value: 0.7670175438596492 and parameters: {'lr': 0.09730790787202513, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 2, 'n_units_l0': 300, 'n_units_l1': 123}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:51:56,505] Trial 26 finished with value: 0.9089473684210526 and parameters: {'lr': 0.014687222267849053, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 2, 'n_units_l0': 440, 'n_units_l1': 409}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:52:02,393] Trial 27 finished with value: 0.913859649122807 and parameters: {'lr': 0.0012612365093757013, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 342}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:52:12,591] Trial 28 finished with value: 0.34192982456140353 and parameters: {'lr': 0.0005541407121416457, 'batch_size': 32, 'optimizer': 'SGD', 'n_layers': 3, 'n_units_l0': 242, 'n_units_l1': 230, 'n_units_l2': 67}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:52:22,325] Trial 29 finished with value: 0.9143859649122807 and parameters: {'lr': 0.00014035763304794273, 'batch_size': 64, 'optimizer': 'Adam', 'n_layers': 2, 'n_units_l0': 286, 'n_units_l1': 111}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:52:28,852] Trial 30 finished with value: 0.9117543859649123 and parameters: {'lr': 0.005473225218935977, 'batch_size': 128, 'optimizer': 'Adam', 'n_layers': 1, 'n_units_l0': 361}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:52:34,320] Trial 31 finished with value: 0.9170175438596492 and parameters: {'lr': 0.0011564638882917613, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 311}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:52:39,717] Trial 32 finished with value: 0.9140350877192982 and parameters: {'lr': 0.0025488749524767984, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 297}. Best is trial 12 with value: 0.9194736842105263.
# [I 2026-01-30 10:52:45,393] Trial 33 finished with value: 0.92 and parameters: {'lr': 0.0014122902270844123, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 347}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:52:51,347] Trial 34 finished with value: 0.9198245614035088 and parameters: {'lr': 0.0015014160650715625, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 396}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:52:57,406] Trial 35 finished with value: 0.913859649122807 and parameters: {'lr': 0.0012805752831642103, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 392}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:52:59,899] Trial 36 finished with value: 0.3333333333333333 and parameters: {'lr': 0.0005158877307205501, 'batch_size': 128, 'optimizer': 'SGD', 'n_layers': 1, 'n_units_l0': 66}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:53:10,079] Trial 37 finished with value: 0.9175438596491228 and parameters: {'lr': 0.0030439483354589634, 'batch_size': 32, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 231}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:53:13,631] Trial 38 finished with value: 0.9145614035087719 and parameters: {'lr': 0.0014398982696005548, 'batch_size': 128, 'optimizer': 'Adam', 'n_layers': 1, 'n_units_l0': 130}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:53:19,878] Trial 39 finished with value: 0.8191228070175438 and parameters: {'lr': 0.006006161161456071, 'batch_size': 64, 'optimizer': 'SGD', 'n_layers': 1, 'n_units_l0': 433}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:53:25,201] Trial 40 finished with value: 0.9175438596491228 and parameters: {'lr': 0.001117824653245738, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 280}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:53:32,205] Trial 41 finished with value: 0.9159649122807018 and parameters: {'lr': 0.0018798517893260892, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 2, 'n_units_l0': 350, 'n_units_l1': 235}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:53:40,602] Trial 42 finished with value: 0.9119298245614035 and parameters: {'lr': 0.0027891899682246325, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 3, 'n_units_l0': 386, 'n_units_l1': 417, 'n_units_l2': 69}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:53:46,462] Trial 43 finished with value: 0.9126315789473685 and parameters: {'lr': 0.00022000683835882783, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 369}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:53:52,501] Trial 44 finished with value: 0.9152631578947369 and parameters: {'lr': 0.0008545491065635605, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 417}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:54:01,112] Trial 45 finished with value: 0.9136842105263158 and parameters: {'lr': 0.0005313550430393469, 'batch_size': 128, 'optimizer': 'Adam', 'n_layers': 2, 'n_units_l0': 323, 'n_units_l1': 327}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:54:06,987] Trial 46 finished with value: 0.92 and parameters: {'lr': 0.0017060866756231777, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 469}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:54:13,080] Trial 47 finished with value: 0.9185964912280702 and parameters: {'lr': 0.0038017391429309186, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 510}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:54:19,806] Trial 48 finished with value: 0.5547368421052632 and parameters: {'lr': 0.0008960286525879682, 'batch_size': 64, 'optimizer': 'SGD', 'n_layers': 1, 'n_units_l0': 478}. Best is trial 33 with value: 0.92.
# [I 2026-01-30 10:54:35,137] Trial 49 finished with value: 0.9159649122807018 and parameters: {'lr': 0.0015314426107886185, 'batch_size': 32, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 466}. Best is trial 33 with value: 0.92.
# Best accuracy: 0.92
# Best hyperparameters: {'lr': 0.0014122902270844123, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 347}

# %%
# Get best params
best_params = study.best_params
print(best_params)
# {'n_layers': 2, 'n_units_l0': 256, 'n_units_l1': 128, 'lr': 0.003, 'batch_size': 64, 'optimizer': 'Adam'}

# Build final model with best architecture
# Train for more epochs with best hyperparameters
# Out:
# {'lr': 0.0014122902270844123, 'batch_size': 128, 'optimizer': 'RMSprop', 'n_layers': 1, 'n_units_l0': 347}
